# %% [markdown]
# # Milestone 1
#
# 'Andik Al Fauzi - FTDS-RMT-018'

# %% [markdown]
# ## Description
#
# ### Objective
#
# `Write your objective here`
#
# ### Problem Statement
#
# 1. Buat Fungsi untuk menghitung Rumus Hambatan dan Daya
# 2. Buat Kolom Baru untuk simpan hasil dari perhitungan rumus
# 3. Hitung nilai  rata- rata kapasitas arus

# %% [markdown]
# ## Working Area
#
# ```txt
# Put your code, analysis, everything below this line
#
# Make sure to check everything the rubric requires before you submit
# ```

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('NMC1-9.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90982 entries, 0 to 90981
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time(s)      90982 non-null  int64
#  1   V_m          90982 non-null  float64
#  2   Current (A)  90982 non-null  float64
#  3   Cycle        90982 non-null  int64
#  4   Cap          90982 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 3.5 MB

# %%
df.head()
# Out:
#    time(s)    V_m  Current (A)  Cycle       Cap
# 0        0  4.098        0.997      1  2.840817
# 1        1  4.096        0.998      1  2.840817
# 2        2  4.094        0.999      1  2.840817
# 3        3  4.093        0.998      1  2.840817
# 4        4  4.092        0.999      1  2.840817

# %%
copyDF = df.copy()

# %% [markdown]
# # Tidak ada data yang null

# %% [markdown]
# # 1. Fungsi untuk menghitung Rumus Hambatan dan Daya

# %%
# Rename Kolom V-M to Volt

copyDF = copyDF.rename(columns={'V_m' : 'Volt'})

# %%
# Rename Kolom Current (A) to Ampere

copyDF = copyDF.rename(columns={'Current (A)' : 'Ampere'})

# %%
copyDF.shape
# Out:
# (90982, 5)

# %%
copyDF.head()
# Out:
#    time(s)   Volt  Ampere  Cycle       Cap
# 0        0  4.098   0.997      1  2.840817
# 1        1  4.096   0.998      1  2.840817
# 2        2  4.094   0.999      1  2.840817
# 3        3  4.093   0.998      1  2.840817
# 4        4  4.092   0.999      1  2.840817

# %%
copyDF.tail()
# Out:
#        time(s)   Volt  Ampere  Cycle      Cap
# 90977    90977  2.506   1.002      9  2.77018
# 90978    90978  2.504   1.002      9  2.77018
# 90979    90979  2.502   1.002      9  2.77018
# 90980    90980  2.500   1.002      9  2.77018
# 90981    90981  2.497   1.002      9  2.77018

# %%
copyDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90982 entries, 0 to 90981
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time(s)  90982 non-null  int64
#  1   Volt     90982 non-null  float64
#  2   Ampere   90982 non-null  float64
#  3   Cycle    90982 non-null  int64
#  4   Cap      90982 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 3.5 MB

# %%
copyDF.describe()
# Out:
#             time(s)          Volt        Ampere         Cycle           Cap
# count  90982.000000  90982.000000  90982.000000  90982.000000  90982.000000
# mean   45490.500000      3.607666      0.999264      4.978699      2.806214
# std    26264.385433      0.322777      0.001997      2.582135      0.023283
# min        0.000000      2.497000      0.993000      1.000000      2.770180
# 25%    22745.250000      3.422000      0.997000      3.000000      2.786860
# 50%    45490.500000      3.636000      0.999000      5.000000      2.804878
# 75%    68235.750000      3.868000      1.001000      7.000000      2.823520
# max    90981.000000      4.114000      1.003000      9.000000      2.840817

# %%
copyDF.index
# Out:
# RangeIndex(start=0, stop=90982, step=1)

# %%
copyDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90982 entries, 0 to 90981
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time(s)  90982 non-null  int64
#  1   Volt     90982 non-null  float64
#  2   Ampere   90982 non-null  float64
#  3   Cycle    90982 non-null  int64
#  4   Cap      90982 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 3.5 MB

# %% [markdown]
# 2. Buat Kolom Baru untuk simpan hasil dari perhitungan rumus

# %%
# Define Rumus Hambatan

def hambatan(row) :
  nValue = copyDF.Volt/copyDF.Ampere
  return nValue

# %%
# Define Rumus Daya

def daya(row) : 
  nValue = copyDF.Volt*copyDF.Ampere
  return nValue

# %%
# Save value from calculation

nValue=[]

# %%
# Looping and Function 

for i in copyDF.Cap :
  if i >= 2.5 : # Jika nilai kolom Cap lebih dari 2.5 maka menggunakan fungsi Daya
    nValue = daya(i)
  elif i <= 2.5 :
    nValue = hambatan(i) # Jika nilai kolom Cap kurang dari 2.5 makan menggunakan fungsi Hambatan

# %%
# Print Value from Function

print(nValue)
# Out:
# 0        4.085706
# 1        4.087808
# 2        4.089906
# 3        4.084814
# 4        4.087908
#            ...
# 90977    2.511012
# 90978    2.509008
# 90979    2.507004
# 90980    2.505000
# 90981    2.501994
# Length: 90982, dtype: float64

# %%
# Inserting data calculation

copyDF['R/P'] = nValue

# %%
# Cek data Value from Calculation
copyDF.loc[copyDF['Cap'] >= 2.5]
# Out:
#        time(s)   Volt  Ampere  Cycle       Cap       R/P
# 0            0  4.098   0.997      1  2.840817  4.085706
# 1            1  4.096   0.998      1  2.840817  4.087808
# 2            2  4.094   0.999      1  2.840817  4.089906
# 3            3  4.093   0.998      1  2.840817  4.084814
# 4            4  4.092   0.999      1  2.840817  4.087908
# ...        ...    ...     ...    ...       ...       ...
# 90977    90977  2.506   1.002      9  2.770180  2.511012
# 90978    90978  2.504   1.002      9  2.770180  2.509008
# 90979    90979  2.502   1.002      9  2.770180  2.507004
# 90980    90980  2.500   1.002      9  2.770180  2.505000
# 90981    90981  2.497   1.002      9  2.770180  2.501994
#
# [90982 rows x 6 columns]

# %%
copyDF.loc[copyDF['Cap'] <= 2.5]
# Out:
# Empty DataFrame
# Columns: [time(s), Volt, Ampere, Cycle, Cap, R/P]
# Index: []

# %%
copyDF
# Out:
#        time(s)   Volt  Ampere  Cycle       Cap       R/P
# 0            0  4.098   0.997      1  2.840817  4.085706
# 1            1  4.096   0.998      1  2.840817  4.087808
# 2            2  4.094   0.999      1  2.840817  4.089906
# 3            3  4.093   0.998      1  2.840817  4.084814
# 4            4  4.092   0.999      1  2.840817  4.087908
# ...        ...    ...     ...    ...       ...       ...
# 90977    90977  2.506   1.002      9  2.770180  2.511012
# 90978    90978  2.504   1.002      9  2.770180  2.509008
# 90979    90979  2.502   1.002      9  2.770180  2.507004
# 90980    90980  2.500   1.002      9  2.770180  2.505000
# 90981    90981  2.497   1.002      9  2.770180  2.501994
#
# [90982 rows x 6 columns]

# %% [markdown]
# # 3. Hitunglah rata-rata nilai kapasitas untuk arus = 1 Ampere dan cycle ganjil.

# %%
copyDF1 = copyDF.loc[(copyDF['Ampere'] == 1) & (copyDF['Cycle'] % 2 != 0)]

# %%
copyDF1
# Out:
#        time(s)   Volt  Ampere  Cycle       Cap    R/P
# 15          15  4.085     1.0      1  2.840817  4.085
# 19          19  4.083     1.0      1  2.840817  4.083
# 20          20  4.083     1.0      1  2.840817  4.083
# 21          21  4.082     1.0      1  2.840817  4.082
# 31          31  4.079     1.0      1  2.840817  4.079
# ...        ...    ...     ...    ...       ...    ...
# 90909    90909  2.640     1.0      9  2.770180  2.640
# 90923    90923  2.615     1.0      9  2.770180  2.615
# 90937    90937  2.589     1.0      9  2.770180  2.589
# 90949    90949  2.565     1.0      9  2.770180  2.565
# 90967    90967  2.528     1.0      9  2.770180  2.528
#
# [6830 rows x 6 columns]

# %%
# Make sure there's no data wrong, where Ampere !=1
copyDF1.loc[(copyDF1['Ampere'] != 1)]
# Out:
# Empty DataFrame
# Columns: [time(s), Volt, Ampere, Cycle, Cap, R/P]
# Index: []

# %%
# Make sure there's no data wrong, where Even in Cycle

copyDF1.loc[(copyDF1['Cycle'] % 2 == 0)]
# Out:
# Empty DataFrame
# Columns: [time(s), Volt, Ampere, Cycle, Cap, R/P]
# Index: []

# %%
# Find the Average

averageDF = copyDF1['Cap'].mean()
averageDF
# Out:
# 2.8064845553927484

# %% [markdown]
# ## Conclusions, Assumptions, Overall Analysis
#
# `Berikut Beberapa kesimpulan yang didapat`

# %% [markdown]
# 1. Jawaban nomor 1 adalah berikut, yaitu define fungsi hambatan dan daya

# %%
# Funsi Hambatan

def hambatan(row) :
  nValue = copyDF.Volt/copyDF.Ampere # Pembagian antara kolom Volt dengan Ampere
  return nValue

# Fungsi Daya

def daya(row) : 
  nValue = copyDF.Volt*copyDF.Ampere # Perkalian antara kolom Volt dengan Ampere
  return nValue

# %% [markdown]
# # 2. Jawaban Nomor 2 adalah menampilkan hasil perhitungan dari Nomor 1

# %%
copyDF
# Out:
#        time(s)   Volt  Ampere  Cycle       Cap       R/P
# 0            0  4.098   0.997      1  2.840817  4.085706
# 1            1  4.096   0.998      1  2.840817  4.087808
# 2            2  4.094   0.999      1  2.840817  4.089906
# 3            3  4.093   0.998      1  2.840817  4.084814
# 4            4  4.092   0.999      1  2.840817  4.087908
# ...        ...    ...     ...    ...       ...       ...
# 90977    90977  2.506   1.002      9  2.770180  2.511012
# 90978    90978  2.504   1.002      9  2.770180  2.509008
# 90979    90979  2.502   1.002      9  2.770180  2.507004
# 90980    90980  2.500   1.002      9  2.770180  2.505000
# 90981    90981  2.497   1.002      9  2.770180  2.501994
#
# [90982 rows x 6 columns]

# %% [markdown]
# # 3. Nilai rata-rata dari Data Cap : 2.8064845553927484

# %%
averageDF
# Out:
# 2.8064845553927484
